# %%
import pandas as pd
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# download once
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\goura\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\goura\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\goura\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# load dataset
df = pd.read_csv("reviews.csv")

def preprocess(text):
    text = text.lower()

    # remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # remove words containing numbers (like 44k, 2024good)
    text = re.sub(r'\w*\d\w*', '', text)

    words = word_tokenize(text)

    # remove stopwords + small junk words
    words = [w for w in words if w not in stop_words and len(w) > 2]

    return " ".join(words)

# %%
df["cleaned_text"] = df["review_text"].apply(preprocess)

# save new file
df.to_csv("cleaned_reviews.csv", index=False)

print(df.head())
# Out:
#                                          review_text  \
# 0  Battery too good, It Feels Premium, If you are...
# 1  Definitely one of the best laptop in it's segm...
# 2  That is nice laptop at this price, if you can ...
# 3  Good product with good design and performance....
# 4  Product is slim good for coders and creators E...
#
#                                         cleaned_text
# 0  battery good feels premium looking overall com...
# 1  definitely one best laptop segment got less la...
# 2  nice laptop price find laptop college work cho...
# 3  good product good design performance comparing...
# 4  product slim good coders creators especially c...
