# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai
from sentence_transformers import SentenceTransformer
from openai import OpenAI

# %%
print("fuck")
# Out:
# fuck

# %%
# Load environment variables from .env file
load_dotenv()

# Get API keys from environment variables
gemini_api_key = os.getenv('GEMINI_TOKEN')
openai_api_key = os.getenv('OPEN_AI_API_KEY')

print(f"Gemini API Key found: {bool(gemini_api_key)}")
print(f"OpenAI API Key found: {bool(openai_api_key)}")
# Out:
# Gemini API Key found: True
# OpenAI API Key found: True

# %%
api_key
# Out:
# 'AIzaSyDt4Q9QPUfL3Z02m_546SB125kzPH264T4'

# %%
# ==================== EMBEDDING FUNCTIONS ====================

# 1. GOOGLE GENERATIVE AI (Gemini)
def get_embedding_gemini(text):
    """Get embeddings using Google's Gemini model"""
    if not gemini_api_key:
        raise ValueError("GEMINI_TOKEN not found in .env file")
    
    genai.configure(api_key=gemini_api_key)
    result = genai.embed_content(
        model='models/gemini-embedding-001',
        content=text,
        task_type='retrieval_document'
    )
    return result['embedding']


# 2. OPENAI (Text Embedding Model)
def get_embedding_openai(text):
    """Get embeddings using OpenAI's embedding model"""
    if not openai_api_key:
        raise ValueError("OPENAI_API_KEY not found in .env file")
    
    client = OpenAI(api_key=openai_api_key)
    response = client.embeddings.create(
        model="text-embedding-3-small",  # or "text-embedding-3-large" for better quality
        input=text
    )
    return response.data[0].embedding


# 3. HUGGING FACE (Sentence Transformers - Local)
def get_embedding_huggingface(text, model_name='sentence-transformers/all-MiniLM-L6-v2'):
    """Get embeddings using Hugging Face Sentence Transformers (runs locally)"""
    model = SentenceTransformer(model_name)
    embedding = model.encode(text)
    return embedding.tolist()


# ==================== WRAPPER FUNCTION ====================
def get_embedding(text, provider='huggingface'):
    """
    Get embeddings using the specified provider
    
    Parameters:
    - text: The input text to embed
    - provider: 'gemini', 'openai', or 'huggingface' (default)
    """
    if provider.lower() == 'gemini':
        return get_embedding_gemini(text)
    elif provider.lower() == 'openai':
        return get_embedding_openai(text)
    elif provider.lower() == 'huggingface':
        return get_embedding_huggingface(text)
    else:
        raise ValueError(f"Unknown provider: {provider}. Use 'gemini', 'openai', or 'huggingface'")


x = 9
if x > 20:
    print("fuck u")
else:
    print("i would rather go for the reason where should i go for this ")

# ==================== EXAMPLE USAGE ====================
sentence = "This is a sample sentence."
paragraph = "This is a sample paragraph. It contains multiple sentences and provides more context for embedding."

# Try with Hugging Face (default - no API key needed)
sentence_embedding1 = get_embedding(sentence, provider='huggingface')
paragraph_embedding1 = get_embedding(paragraph, provider='huggingface')
sentence_embedding2 = get_embedding(sentence, provider='openAi')
paragraph_embedding2 = get_embedding(paragraph, provider='openai')
sentence_embedding3 = get_embedding(sentence, provider='gemini')
paragraph_embedding3 = get_embedding(paragraph, provider='gemini')

print(f"Sentence embedding length (Hugging Face): {len(sentence_embedding)}")
print(f"Paragraph embedding length (Hugging Face): {len(paragraph_embedding)}")
# Out:
# Sentence embedding length (Hugging Face): 1536
# Paragraph embedding length (Hugging Face): 384

# %%
print(sentence_embedding1[0], sentence_embedding2[0], sentence_embedding3[0])
# Out:
# 0.07780639827251434 0.0535888671875 -0.02412265

# %%
len(paragraph_embedding)
# Out:
# 3072

# %%
# ==================== TEST OPENAI EMBEDDINGS ====================
# Uncomment below to test OpenAI (requires OPENAI_API_KEY in .env)

# sentence_embedding_openai = get_embedding(sentence, provider='openai')
# paragraph_embedding_openai = get_embedding(paragraph, provider='openai')
# 
# print(f"Sentence embedding length (OpenAI): {len(sentence_embedding_openai)}")
# print(f"Paragraph embedding length (OpenAI): {len(paragraph_embedding_openai)}")
# Out:
# c:\Users\goura\OneDrive\Desktop\modern-gen-ai\ai_env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\goura\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# ==================== TEST GEMINI EMBEDDINGS ====================
# Uncomment below to test Gemini (requires GEMINI_TOKEN in .env)

# sentence_embedding_gemini = get_embedding(sentence, provider='gemini')
# paragraph_embedding_gemini = get_embedding(paragraph, provider='gemini')
# 
# print(f"Sentence embedding length (Gemini): {len(sentence_embedding_gemini)}")
# print(f"Paragraph embedding length (Gemini): {len(paragraph_embedding_gemini)}")
# Out:
# 384

# %%
# ==================== COMPARISON: SIMILARITY BETWEEN EMBEDDINGS ====================
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Compare embeddings from different providers
hf_embeddings = [
    get_embedding(sentence, provider='huggingface'),
    get_embedding(paragraph, provider='huggingface')
]

# Calculate similarity between sentence and paragraph
similarity = cosine_similarity([hf_embeddings[0]], [hf_embeddings[1]])[0][0]
print(f"Cosine similarity (Sentence vs Paragraph): {similarity:.4f}")
# Out:
# Cosine similarity (Sentence vs Paragraph): 0.5705
